# %%
import sys
sys.path.insert(0, "/home/o/proj/logmgtfolder/logmanager")

# %%
# TEST DATA PREPROCESSING
from src.preprocess import clean_log_message
clean_log_message('192.168.0.8')
clean_log_message('400')
clean_log_message('usr_12345')
# clean_log_message('ERROR: (Database-Connection)')
# clean_log_message("error      database      timeout")
# clean_log_message("ERROR: Connection refused from 192.168.1.10 on port 5432.")
# Out:
# '<id>'
